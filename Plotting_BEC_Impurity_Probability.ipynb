# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import matplotlib 

font = {'family' : 'serif',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

dir = "./"
file = "probabilities.txt"
fn=np.loadtxt(dir+file, dtype=np.double)
nowcol = 'r'
nowpt = 'o'

for j in range(9,18):
        print(j*41+1,":",(j+1)*(41))
    
for j in range(0,10):#The range in which I am looping over is dependant on where I stop time.
    plt.plot(fn[j*41:(j+1)*(41),10], fn[j*41:(j+1)*(41),0], ls='--', label=r'$v=$%.5s '%((j+1)*0.001))


plt.legend(bbox_to_anchor=(0.05, 0.94), loc=2, borderaxespad=0, prop={'size':11.95})
#nowcol+nowpt, mfc='none', mec=nowcol, mew=0.8, markersize=1,

nowcol = 'b'
nowpt = 'o'

plt.ticklabel_format(useOffset=False)
#plt.title("Ground state probability for the BEC-impurity model")
plt.xlabel("$W(t)$")
plt.ylabel(r"$P_0(t)$")
plt.tight_layout()
#plt.yticks(np.arange(0.0, 1, step=.2))
#plt.yscale('log')

plt.show()
#plt.savefig("./"+'ProbN=50_defense.jpg',dpi=300)
# Out:
# 370 : 410
# 411 : 451
# 452 : 492
# 493 : 533
# 534 : 574
# 575 : 615
# 616 : 656
# 657 : 697
# 698 : 738
